# %%
import sqlite3 as sq
import pandas as pd
import numpy as np

# %%
conn = sq.connect('FPA_FOD_20221014.sqlite')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
query = "SELECT * FROM sqlite_master;"
df = pd.read_sql(query, conn)

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
for table in tables:
    print(table)
# Out:
# ('spatial_ref_sys',)
# ('spatialite_history',)
# ('sqlite_sequence',)
# ('geometry_columns',)
# ('views_geometry_columns',)
# ('virts_geometry_columns',)
# ('geometry_columns_statistics',)
# ('views_geometry_columns_statistics',)
# ('virts_geometry_columns_statistics',)
# ('geometry_columns_field_infos',)
# ('views_geometry_columns_field_infos',)
# ('virts_geometry_columns_field_infos',)
# ('geometry_columns_time',)
# ('geometry_columns_auth',)
# ('views_geometry_columns_auth',)
# ('virts_geometry_columns_auth',)
# ('sql_statements_log',)
# ('SpatialIndex',)
# ('NWCG_UnitIdActive_20200123',)
# ('Fires',)
# ('idx_Fires_Shape',)
# ('idx_Fires_Shape_rowid',)
# ('idx_Fires_Shape_node',)
# ('idx_Fires_Shape_parent',)

# %%
import pandas as pd
query = "SELECT * FROM sqlite_master;"
df = pd.read_sql(query, conn)

# %%
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
print(df.head())  # Display the first few rows
# Out:
# (117, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      117 non-null    object
#  1   name      117 non-null    object
#  2   tbl_name  117 non-null    object
#  3   rootpage  117 non-null    int64
#  4   sql       104 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ KB
# None
#     type                 name            tbl_name  rootpage  \
# 0  table      spatial_ref_sys     spatial_ref_sys         2
# 1  index  idx_spatial_ref_sys     spatial_ref_sys         3
# 2  table   spatialite_history  spatialite_history         4
# 3  table      sqlite_sequence     sqlite_sequence         5
# 4  table     geometry_columns    geometry_columns         6
#
#                                                  sql
# 0  CREATE TABLE spatial_ref_sys (\nsrid INTEGER N...
# ...

# %%
with open("table_names.txt", "w") as file:
    for table in df:  # Assuming table_names is the list of your tables
        file.write(table + "\n")

# %%
cursor.execute("SELECT * FROM Fires LIMIT 5;")
tables = cursor.fetchall()
query = "SELECT * FROM Fires LIMIT 5;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
df.head()  # Display the first few rows
# Out:
# (5, 39)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   OBJECTID                       5 non-null      int64
#  1   Shape                          5 non-null      object
#  2   FOD_ID                         5 non-null      int64
#  3   FPA_ID                         5 non-null      object
#  4   SOURCE_SYSTEM_TYPE             5 non-null      object
#  5   SOURCE_SYSTEM                  5 non-null      object
#  6   NWCG_REPORTING_AGENCY          5 non-null      object
#  7   NWCG_REPORTING_UNIT_ID         5 non-null      object
#  8   NWCG_REPORTING_UNIT_NAME       5 non-null      object
#  9   SOURCE_REPORTING_UNIT          5 non-null      object
#  10  SOURCE_REPORTING_UNIT_NAME     5 non-null      object
#  11  LOCAL_FIRE_REPORT_ID           5 non-null      object
# ...

# %%
df.head(5)
# Out:
#    OBJECTID                                              Shape  FOD_ID  \
# 0         1  b'\x00\x01\xad\x10\x00\x00\xc8\xce\n[_@^\xc0\x...       1
#
#        FPA_ID SOURCE_SYSTEM_TYPE SOURCE_SYSTEM NWCG_REPORTING_AGENCY  \
# 0  FS-1418826                FED   FS-FIRESTAT                    FS
#
#   NWCG_REPORTING_UNIT_ID NWCG_REPORTING_UNIT_NAME SOURCE_REPORTING_UNIT  ...  \
# 0                USCAPNF   Plumas National Forest                  0511  ...
#
#   CONT_TIME FIRE_SIZE FIRE_SIZE_CLASS   LATITUDE   LONGITUDE OWNER_DESCR  \
# 0      1730       0.1               A  40.036944 -121.005833        USFS
#
#   STATE COUNTY FIPS_CODE      FIPS_NAME
# 0    CA     63     06063  Plumas County
#
# [1 rows x 39 columns]

# %%
query = "SELECT * FROM Fires WHERE FIRE_YEAR > 1995 LIMIT 100;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
print(df.head(5))  # Display the first few rows
df.to_csv('over2000.csv', index=False)
# Out:
# (100, 39)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   OBJECTID                       100 non-null    int64
#  1   Shape                          100 non-null    object
#  2   FOD_ID                         100 non-null    int64
#  3   FPA_ID                         100 non-null    object
#  4   SOURCE_SYSTEM_TYPE             100 non-null    object
#  5   SOURCE_SYSTEM                  100 non-null    object
#  6   NWCG_REPORTING_AGENCY          100 non-null    object
#  7   NWCG_REPORTING_UNIT_ID         100 non-null    object
#  8   NWCG_REPORTING_UNIT_NAME       100 non-null    object
#  9   SOURCE_REPORTING_UNIT          100 non-null    object
#  10  SOURCE_REPORTING_UNIT_NAME     100 non-null    object
#  11  LOCAL_FIRE_REPORT_ID           100 non-null    object
# ...

# %%
query = "SELECT count(*) FROM Fires;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
print(df.head(5))  # Display the first few rows
# Out:
# (1, 1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   count(*)  1 non-null      int64
# dtypes: int64(1)
# memory usage: 136.0 bytes
# None
#    count(*)
# 0   2303566

# %%
query = "SELECT FIRE_YEAR, count(*) FROM Fires GROUP BY FIRE_YEAR;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
print(df.head(40))  # Display the first few rows
# Out:
# (29, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FIRE_YEAR  29 non-null     int64
#  1   count(*)   29 non-null     int64
# dtypes: int64(2)
# memory usage: 592.0 bytes
# None
#     FIRE_YEAR  count(*)
# 0        1992     67961
# 1        1993     61975
# 2        1994     75932
# 3        1995     71440
# 4        1996     75561
# 5        1997     61442
# 6        1998     68356
# 7        1999     89350
# 8        2000     96396
# 9        2001     87001
# 10       2002     76128
# 11       2003     68275
# 12       2004     69370
# 13       2005     92921
# 14       2006    117943
# 15       2007     98837
# 16       2008     88306
# 17       2009     81492
# 18       2010     85579
# 19       2011     98903
# 20       2012     74258
# 21       2013     66434
# 22       2014     70480
# 23       2015     77275
# ...

# %%
# query = "SELECT * FROM Fires;"
# df = pd.read_sql(query, conn)
# print(df.shape)  # Get the number of rows and columns
# print(df.info())  # Get column names, non-null counts, and data types
# print(df.head(5))  # Display the first few rows
# df.to_csv('fires.csv', index=False)
# Out:
# (2303566, 39)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2303566 entries, 0 to 2303565
# Data columns (total 39 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   OBJECTID                       int64
#  1   Shape                          object
#  2   FOD_ID                         int64
#  3   FPA_ID                         object
#  4   SOURCE_SYSTEM_TYPE             object
#  5   SOURCE_SYSTEM                  object
#  6   NWCG_REPORTING_AGENCY          object
#  7   NWCG_REPORTING_UNIT_ID         object
#  8   NWCG_REPORTING_UNIT_NAME       object
#  9   SOURCE_REPORTING_UNIT          object
#  10  SOURCE_REPORTING_UNIT_NAME     object
#  11  LOCAL_FIRE_REPORT_ID           object
#  12  LOCAL_INCIDENT_ID              object
#  13  FIRE_CODE                      object
#  14  FIRE_NAME                      object
#  15  ICS_209_PLUS_INCIDENT_JOIN_ID  object
#  16  ICS_209_PLUS_COMPLEX_JOIN_ID   object
# ...

# %%
conn.close()

# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
profile = ProfileReport(df, title="Wildfires_Fires_Profile_Report")

# %%
profile.to_file("Wildfires_Fires_Profile_Report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
cursor.execute("SELECT * FROM spatial_ref_sys LIMIT 5;")
tables = cursor.fetchall()
query = "SELECT * FROM spatial_ref_sys LIMIT 5;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
print(df.head())  # Display the first few rows
# Out:
# (5, 6)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   srid          5 non-null      int64
#  1   auth_name     5 non-null      object
#  2   auth_srid     5 non-null      int64
#  3   ref_sys_name  5 non-null      object
#  4   proj4text     5 non-null      object
#  5   srtext        5 non-null      object
# dtypes: int64(2), object(4)
# memory usage: 368.0+ bytes
# None
#    srid auth_name  auth_srid                              ref_sys_name  \
# 0    -1      NONE         -1                     Undefined - Cartesian
# 1     0      NONE          0           Undefined - Geographic Long/Lat
# 2  2000      epsg       2000  Anguilla 1957 / British West Indies Grid
# 3  2001      epsg       2001   Antigua 1943 / British West Indies Grid
# 4  2002      epsg       2002  Dominica 1945 / British West Indies Grid
#
# ...

# %%
cursor.execute("SELECT * FROM spatialite_history LIMIT 5;")
tables = cursor.fetchall()
query = "SELECT * FROM spatialite_history LIMIT 5;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
df.head()  # Display the first few rows
# Out:
# (5, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   event_id         5 non-null      int64
#  1   table_name       5 non-null      object
#  2   geometry_column  0 non-null      object
#  3   event            5 non-null      object
#  4   timestamp        5 non-null      object
#  5   ver_sqlite       5 non-null      object
#  6   ver_splite       5 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 408.0+ bytes
# None
#    event_id        table_name geometry_column  \
# 0         1   spatial_ref_sys            None
# 1         2  geometry_columns            None
# 2         3  geometry_columns            None
# 3         4  geometry_columns            None
# 4         5  geometry_columns            None
#
#                                                event  \
# ...

# %%
cursor.execute("SELECT * FROM sqlite_sequence LIMIT 5;")
tables = cursor.fetchall()
query = "SELECT * FROM sqlite_sequence LIMIT 5;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
df.head()  # Display the first few rows
# Out:
# (3, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   seq     3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 176.0+ bytes
# None
#                          name      seq
# 0          spatialite_history       24
# 1  NWCG_UnitIdActive_20200123     5971
# 2                       Fires  2303566

# %%
cursor.execute("SELECT * FROM NWCG_UnitIdActive_20200123 LIMIT 5;")
tables = cursor.fetchall()
query = "SELECT * FROM NWCG_UnitIdActive_20200123 LIMIT 5;"
df = pd.read_sql(query, conn)
print(df.shape)  # Get the number of rows and columns
print(df.info())  # Get column names, non-null counts, and data types
df.head()  # Display the first few rows
# Out:
# (5, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OBJECTID        5 non-null      int64
#  1   UnitId          5 non-null      object
#  2   GeographicArea  5 non-null      object
#  3   Gacc            5 non-null      object
#  4   WildlandRole    5 non-null      object
#  5   UnitType        5 non-null      object
#  6   Department      0 non-null      object
#  7   Agency          0 non-null      object
#  8   Parent          0 non-null      object
#  9   Country         5 non-null      object
#  10  State           5 non-null      object
#  11  Code            5 non-null      object
#  12  Name            5 non-null      object
# dtypes: int64(1), object(12)
# memory usage: 648.0+ bytes
# None
#    OBJECTID    UnitId GeographicArea      Gacc              WildlandRole  \
# ...

# %%
conn.close()

# %%
del(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   OBJECTID                       5 non-null      int64
#  1   Shape                          5 non-null      object
#  2   FOD_ID                         5 non-null      int64
#  3   FPA_ID                         5 non-null      object
#  4   SOURCE_SYSTEM_TYPE             5 non-null      object
#  5   SOURCE_SYSTEM                  5 non-null      object
#  6   NWCG_REPORTING_AGENCY          5 non-null      object
#  7   NWCG_REPORTING_UNIT_ID         5 non-null      object
#  8   NWCG_REPORTING_UNIT_NAME       5 non-null      object
#  9   SOURCE_REPORTING_UNIT          5 non-null      object
#  10  SOURCE_REPORTING_UNIT_NAME     5 non-null      object
#  11  LOCAL_FIRE_REPORT_ID           5 non-null      object
# ...

# %%
query = "SELECT NWCG_GENERAL_CAUSE, avg(FIRE_SIZE) FROM Fires GROUP BY NWCG_GENERAL_CAUSE ORDER BY 2 DESC;"
df = pd.read_sql(query, conn)
df
# Out:
#                             NWCG_GENERAL_CAUSE  avg(FIRE_SIZE)
# 0                                      Natural      322.733929
# 1                  Firearms and explosives use      237.010874
# 2   Power generation/transmission/distribution      107.500738
# 3      Missing data/not specified/undetermined       56.383735
# 4                    Equipment and vehicle use       52.205821
# 5                      Recreation and ceremony       46.792310
# 6                                 Other causes       42.564584
# 7                           Arson/incendiarism       33.609560
# 8                                    Fireworks       29.430753
# 9          Railroad operations and maintenance       25.328746
# 10                                     Smoking       14.787225
# 11                     Debris and open burning       14.543816
# 12                   Misuse of fire by a minor        7.410340

# %%
conn = sq.connect('FPA_FOD_20221014.sqlite')
cursor = conn.cursor()
query = "SELECT NWCG_GENERAL_CAUSE, avg(FIRE_SIZE) FROM Fires GROUP BY NWCG_GENERAL_CAUSE ORDER BY 2 DESC;"
df = pd.read_sql(query, conn)
df.to_csv(f'{query}.csv', index=False)
df
# Out:
#                             NWCG_GENERAL_CAUSE  avg(FIRE_SIZE)
# 0                                      Natural      322.733929
# 1                  Firearms and explosives use      237.010874
# 2   Power generation/transmission/distribution      107.500738
# 3      Missing data/not specified/undetermined       56.383735
# 4                    Equipment and vehicle use       52.205821
# 5                      Recreation and ceremony       46.792310
# 6                                 Other causes       42.564584
# 7                           Arson/incendiarism       33.609560
# 8                                    Fireworks       29.430753
# 9          Railroad operations and maintenance       25.328746
# 10                                     Smoking       14.787225
# 11                     Debris and open burning       14.543816
# 12                   Misuse of fire by a minor        7.410340

# %%
conn.close()

# %%
conn = sq.connect('FPA_FOD_20221014.sqlite')
cursor = conn.cursor()
query = """
SELECT NWCG_GENERAL_CAUSE, COUNT(NWCG_GENERAL_CAUSE) as Frequency
FROM Fires
GROUP BY NWCG_GENERAL_CAUSE
"""
df = pd.read_sql(query, conn)
mode_df = df[df['Frequency'] == df['Frequency'].max()]
# Save to CSV (replacing problematic characters in the filename)

print(mode_df)
# Out:
#                         NWCG_GENERAL_CAUSE  Frequency
# 5  Missing data/not specified/undetermined     597933

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NWCG_GENERAL_CAUSE  13 non-null     object
#  1   Frequency           13 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 336.0+ bytes
